# %%
import pandas as pd

df = pd.read_csv('annual-enterprise-survey-2023-financial-year-provisional-size-bands.csv', sep=',')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#       year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0     2011                    A  Agriculture, Forestry and Fishing
# 1     2011                    A  Agriculture, Forestry and Fishing
# 2     2011                    A  Agriculture, Forestry and Fishing
# 3     2011                    A  Agriculture, Forestry and Fishing
# 4     2011                    A  Agriculture, Forestry and Fishing
# ...    ...                  ...                                ...
# 6180  2019                    A  Agriculture, Forestry and Fishing
# 6181  2019                    A  Agriculture, Forestry and Fishing
# 6182  2019                    A  Agriculture, Forestry and Fishing
# 6183  2019                    A  Agriculture, Forestry and Fishing
# 6184  2019                    A  Agriculture, Forestry and Fishing
#
#      rme_size_grp                                         variable  value  \
# ...

# %%
Размер df

# %%
df.shape
# Out:
# (20124, 7)

# %%
df.iloc[1]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                           Rolling mean employees
# value                                                   0
# unit                                                COUNT
# Name: 1, dtype: object

# %%
df.iloc[1:4]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable value               unit
# 1                           Rolling mean employees     0              COUNT
# 2                          Salaries and wages paid   279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies  8187  DOLLARS(millions)

# %%
year = df['year']
year == 2014
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20119    False
# 20120    False
# 20121    False
# 20122    False
# 20123    False
# Name: year, Length: 20124, dtype: bool

# %%
df['year'].value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='year'>

# %%
df.sort_values(by='value',ascending=False).head()
# Out:
#       year industry_code_ANZSIC                        industry_name_ANZSIC  \
# 4468  2016                    R                Arts and Recreation Services
# 3346  2016                    D  Electricity, Gas, Water and Waste Services
# 691   2012                    O            Public Administration and Safety
# 5079  2017                    R                Arts and Recreation Services
# 689   2012                    O            Public Administration and Safety
#
#           rme_size_grp                                         variable value  \
# 4468            h_200+  Sales, government funding, grants and subsidies     C
# 3346  i_Industry_Total                      Operating profit before tax     C
# 691          g_100-199                            Fixed tangible assets     C
# 5079           e_20-49                      Operating profit before tax     C
# 689          g_100-199                      Operating profit before tax     C
#
#                    unit
# ...

# %%
df.nlargest(5,['year'])
# Out:
#       year industry_code_ANZSIC               industry_name_ANZSIC  \
# 6121  2019                    A  Agriculture, Forestry and Fishing
# 6122  2019                    A  Agriculture, Forestry and Fishing
# 6123  2019                    A  Agriculture, Forestry and Fishing
# 6124  2019                    A  Agriculture, Forestry and Fishing
# 6125  2019                    A  Agriculture, Forestry and Fishing
#
#      rme_size_grp                                         variable  value  \
# 6121          a_0                                    Activity unit  40890
# 6122          a_0                           Rolling mean employees      0
# 6123          a_0                          Salaries and wages paid    432
# 6124          a_0  Sales, government funding, grants and subsidies  11311
# 6125          a_0                                     Total income  12554
#
#                    unit
# 6121              COUNT
# 6122              COUNT
# 6123  DOLLARS(millions)
# ...

# %%
df.sort_values(by=['value','year'],ascending=[True,True]).head()
# Out:
#       year industry_code_ANZSIC               industry_name_ANZSIC  \
# 2094  2014                    H    Accommodation and Food Services
# 3003  2014                    S                     Other Services
# 4210  2016                    O   Public Administration and Safety
# 4845  2017                    O   Public Administration and Safety
# 2184  2014                    I  Transport, Postal and Warehousing
#
#      rme_size_grp                     variable value               unit
# 2094        c_6-9  Operating profit before tax    -1  DOLLARS(millions)
# 3003      e_20-49  Operating profit before tax    -1  DOLLARS(millions)
# 4210      f_50-99  Operating profit before tax    -1  DOLLARS(millions)
# 4845      f_50-99  Operating profit before tax    -1  DOLLARS(millions)
# 2184      d_10-19  Operating profit before tax   -10  DOLLARS(millions)

# %%
df[(df['value'] == 'C') & (df.year.isin([2012, 2014]))]
# Out:
#       year industry_code_ANZSIC                      industry_name_ANZSIC  \
# 231   2012                    J  Information Media and Telecommunications
# 285   2012                    J  Information Media and Telecommunications
# 327   2012                    K          Financial and Insurance Services
# 329   2012                    K          Financial and Insurance Services
# 349   2012                    K          Financial and Insurance Services
# 354   2012                    K          Financial and Insurance Services
# 356   2012                    K          Financial and Insurance Services
# 358   2012                    K          Financial and Insurance Services
# 365   2012                    K          Financial and Insurance Services
# 655   2012                    O          Public Administration and Safety
# 680   2012                    O          Public Administration and Safety
# 689   2012                    O          Public Administration and Safety
# ...

# %%
df[(df['year'] > df['year'].mean()) & (df['value']=='0')]
# Out:
#       year industry_code_ANZSIC  \
# 3052  2015                    A
# 3107  2016                    B
# 3188  2016                    C
# 3269  2016                    D
# 3350  2016                    E
# 3431  2016                    F
# 3512  2016                    G
# 3593  2016                    H
# 3674  2016                    I
# 3755  2016                    J
# 3836  2016                    K
# 3917  2016                    L
# 3998  2016                    M
# 4079  2016                    N
# 4160  2016                    O
# 4241  2016                    P
# 4322  2016                    Q
# 4403  2016                    R
# 4484  2016                    S
# 4574  2017                    A
# 4714  2017                    N
# 4795  2017                    O
# 4876  2017                    P
# 4957  2017                    Q
# 5038  2017                    R
# 5119  2017                    S
# 5209  2018                    A
# 5290  2018                    B
# ...

# %%
df[df['rme_size_grp'] == 'a_0']['year'].mean()
# Out:
# np.float64(2014.8846715328468)

# %%
df.reset_index()
# Out:
#       index  year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0         0  2011                    A  Agriculture, Forestry and Fishing
# 1         1  2011                    A  Agriculture, Forestry and Fishing
# 2         2  2011                    A  Agriculture, Forestry and Fishing
# 3         3  2011                    A  Agriculture, Forestry and Fishing
# 4         4  2011                    A  Agriculture, Forestry and Fishing
# ...     ...   ...                  ...                                ...
# 6180   6180  2019                    A  Agriculture, Forestry and Fishing
# 6181   6181  2019                    A  Agriculture, Forestry and Fishing
# 6182   6182  2019                    A  Agriculture, Forestry and Fishing
# 6183   6183  2019                    A  Agriculture, Forestry and Fishing
# 6184   6184  2019                    A  Agriculture, Forestry and Fishing
#
#      rme_size_grp                                         variable  value  \
# ...

# %%
df['industry_code_ANZSIC'] == 'A'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6180    True
# 6181    True
# 6182    True
# 6183    True
# 6184    True
# Name: industry_code_ANZSIC, Length: 6185, dtype: bool
